# %%
import matplotlib.pyplot as plt
import numpy as np

# Extracted overall results from the document
overall_results = [
    12.74, 15.05, 17.09, 15.34, 3.71, 11.32, 15.69, 13.55, 14.27, 9.24,
    13.70, 14.27, 9.02, 13.30, 14.14, 14.14, 6.60, 11.12, 13.50, 13.15,
    12.04, 10.10, 12.82, 8.62, 13.55, 15.10, 13.74, 10.14, 14.00, 13.02,
    14.12, 11.70, 11.12, 14.64, 8.12, 12.10, 6.11, 11.82, 12.50, 11.52,
    14.12, 14.24, 11.85, 11.80, 10.32, 10.44, 13.04, 10.02, 16.60, 8.04,
    10.92, 10.20, 11.10, 8.62, 12.22, 7.80, 16.70, 10.94, 15.20, 15.50,
    12.72, 14.85, 14.10, 14.10, 11.94, 11.00, 15.22, 12.10, 9.07, 15.42,
    0.36, 6.67, 4.49, 9.35, 0.18, 0.18, 8.05
]

# Adjusted histogram with xticks from 0 to 20 and optimized bin count
plt.figure(figsize=(9, 6))
plt.hist(overall_results, bins=np.arange(0,21,1), color='skyblue', edgecolor='black',align='left')  # Increased bins for finer detail
plt.xlabel('Overall Result')
plt.ylabel('Frequency')
plt.title('Python Overall Results')
plt.xticks(np.arange(0, 21, 1))  # Set xticks from 0 to 20
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Extracted overall results from the second document
overall_results_2 = [
    9.50, 8.00, 9.40, 3.70, 4.40, 3.20, 12.45, 11.30, 9.20, 8.40,
    11.70, 14.40, 4.10, 3.60, 7.50, 10.30, 9.20, 11.00, 6.50, 4.40,
    13.24, 10.35, 12.50, 6.40, 11.80, 14.40, 18.25, 6.10, 14.40, 12.50,
    7.10, 4.80, 7.30, 10.70, 8.30, 5.70, 7.00, 12.10, 7.55, 14.60,
    10.00, 13.30, 3.60, 14.00, 1.80, 2.40, 6.50, 10.50, 14.30, 5.60,
    12.85, 13.20, 5.40, 8.20, 12.10, 13.80, 11.10, 7.10, 8.60, 14.10,
    9.70, 13.30, 8.70, 15.10, 2.40, 4.60, 11.90, 7.60, 14.40, 17.20,
    8.50, 2.40, 15.80, 7.20, 7.90, 15.10, 6.40, 6.60, 9.40, 12.20,
    10.60, 15.05, 14.20, 4.80, 9.10, 12.50, 5.60, 13.40, 17.60, 15.40,
    5.40, 7.70, 5.60, 8.50, 12.20, 13.30, 10.70, 14.70, 17.10, 10.30,
    10.10, 3.70, 9.10, 9.40, 16.20, 11.70, 9.20, 11.90, 12.00, 7.40,
    9.60, 1.60, 7.70, 7.40, 15.30, 8.50, 13.70, 7.30, 6.60, 8.40,
    10.60, 3.60, 11.60, 4.50, 13.45, 16.80, 14.80, 4.50, 7.00, 6.50,
    7.40, 5.30, 13.90, 5.50, 14.70, 8.90, 13.30, 8.50, 8.70, 12.65,
    11.85, 11.65, 12.30, 8.70, 4.50, 2.00, 7.70, 17.10, 11.45, 2.50,
    6.00, 12.80, 5.10, 6.10, 16.30, 2.00, 4.90, 10.60, 9.80, 11.90
]

# Plot histogram with properly aligned bins
plt.figure(figsize=(10, 6))
plt.hist(overall_results_2, bins=np.arange(0, 21, 1), color='lightcoral', edgecolor='black', align='left')
plt.xlabel('Overall Result')
plt.ylabel('Frequency')
plt.title('ADS Overall Result')
plt.xticks(np.arange(0, 21, 1))  # Set xticks from 0 to 20
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
